# %% [markdown]
# #### importing modules

# %%
! pip install -q yfinance

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# from pandas_datareader.data import DataReader
import yfinance as yf


from datetime import datetime

# %%
from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# #### downloading latest data of tech companies

# %%
companies = ['AAPL', 'GOOG', 'MSFT', 'AMZN']
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in companies:
    globals()[stock] = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #### Creating a dataframe

# %%
company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name

# %%
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-25  119.650002  121.320000  118.949997  120.599998  120.599998
# 2022-10-26  116.000000  119.349998  114.760002  115.660004  115.660004
# 2022-10-27  113.919998  114.120003  109.769997  110.959999  110.959999
# 2022-10-28   97.910004  103.959999   97.660004  103.410004  103.410004
# 2022-10-31  103.559998  104.870003  100.739998  102.440002  102.440002
# 2022-11-01  103.989998  104.580002   96.059998   96.790001   96.790001
# 2022-11-02   97.320000   97.739998   92.010002   92.120003   92.120003
# 2022-11-03   92.470001   93.500000   89.019997   89.300003   89.300003
# 2022-11-04   91.489998   92.440002   88.040001   90.980003   90.980003
# 2022-11-07   91.949997   92.099998   89.040001   90.529999   90.529999
#
#                Volume company_name
# Date
# 2022-10-25   50934600       AMAZON
# 2022-10-26   68802300       AMAZON
# 2022-10-27  129605400       AMAZON
# 2022-10-28  223133400       AMAZON
# 2022-10-31   99251400       AMAZON
# 2022-11-01  153370000       AMAZON
# 2022-11-02  135761800       AMAZON
# 2022-11-03  136683300       AMAZON
# 2022-11-04  128999900       AMAZON
# 2022-11-07   77333800       AMAZON

# %% [markdown]
# #### Company stats

# %%
for name in company_name:
    print("Company : {}".format(name))
    display(df[df['company_name']==name].describe())
    print()
# Out:
# Company : APPLE
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   158.268690  160.458889  156.261349  158.421270  157.825560
# std     12.670763   12.496028   12.684859   12.607882   12.425795
# min    130.070007  132.389999  129.039993  130.059998  129.664490
# 25%    148.167500  150.204998  146.509995  148.650005  148.197964
# 50%    159.580002  161.970001  156.625000  159.260002  158.614716
# 75%    169.232502  171.057503  167.220001  168.970005  168.350849
# max    182.630005  182.940002  179.119995  182.009995  180.959732
#
#              Volume
# count  2.520000e+02
# mean   9.115785e+07
# std    2.645123e+07
# min    4.100000e+07
# 25%    7.334385e+07
# 50%    8.655425e+07
# 75%    1.038220e+08
# max    1.954327e+08
# Company : GOOGLE
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   123.124418  124.715437  121.444881  122.985405  122.985405
# std     16.744490   16.592165   16.618551   16.619207   16.619207
# min     85.510002   86.550003   83.449997   83.489998   83.489998
# 25%    110.814497  112.428253  109.128189  110.696625  110.696625
# 50%    119.274750  121.046627  117.689999  119.458748  119.458748
# 75%    137.973873  139.839947  136.565876  138.034744  138.034744
# max    151.863495  152.100006  149.887497  150.709000  150.709000
#
#              Volume
# count  2.520000e+02
# mean   2.813766e+07
# std    1.070220e+07
# min    1.246400e+07
# 25%    2.124150e+07
# 50%    2.563350e+07
# 75%    3.247755e+07
# max    8.975000e+07
# Company : MICROSOFT
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   282.709008  286.099722  278.821349  282.439524  281.392071
# std     32.250361   32.000949   32.121773   32.139664   31.396689
# min    217.550003  220.410004  213.429993  214.250000  214.250000
# 25%    257.840012  260.877510  253.667496  258.412491  258.233826
# 50%    281.014999  285.169998  276.975006  280.619995  279.519272
# 75%    305.200005  309.289993  300.152504  304.070000  302.615005
# max    344.619995  349.670013  342.200012  343.109985  340.882812
#
#              Volume
# count  2.520000e+02
# mean   3.102793e+07
# std    1.096967e+07
# min    1.504200e+07
# 25%    2.323672e+07
# 50%    2.939630e+07
# 75%    3.524855e+07
# max    9.042890e+07
# Company : AMAZON
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   138.707060  140.923871  136.234528  138.463750  138.463750
# std     24.108333   23.977388   24.091085   23.977214   23.977214
# min     91.489998   92.099998   88.040001   89.300003   89.300003
# 25%    115.767500  118.299999  113.772503  115.824999  115.824999
# 50%    139.968750  142.359253  137.073250  138.859001  138.859001
# 75%    158.847744  161.694248  157.251125  159.549995  159.549995
# max    185.634506  188.107498  183.785995  184.802994  184.802994
#
#              Volume
# count  2.520000e+02
# mean   7.360167e+07
# std    3.350418e+07
# min    3.575400e+07
# 25%    5.346320e+07
# 50%    6.405900e+07
# 75%    8.234812e+07
# max    2.726620e+08

# %% [markdown]
# #### Data Wrangling

# %% [markdown]
# ##### Trend of Adj close price

# %%
plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {company_name[i - 1]}")
    plt.grid(0)
plt.tight_layout()

# %% [markdown]
# ##### Trend of Volume

# %%
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {company_name[i - 1]}")
    plt.grid(0)
plt.tight_layout()

# %% [markdown]
# ##### Trend of Moving average

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
ax = fig.gca()
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')
ax.grid(0)
fig.tight_layout()

# %% [markdown]
# ##### Histogram of Daily Return

# %%
plt.figure(figsize=(12, 7))
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')
    plt.grid(0)
plt.tight_layout()

# %% [markdown]
# #### Modeling

# %%
# predicting stock value for only company for the list
dataset = df[df['company_name']=="APPLE"]

# %%
dataset.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-08  151.410004  151.570007  150.160004  150.440002  149.571930
# 2021-11-09  150.199997  151.429993  150.059998  150.809998  149.939774
# 2021-11-10  150.020004  150.130005  147.850006  147.919998  147.066467
# 2021-11-11  148.960007  149.429993  147.679993  147.869995  147.016739
# 2021-11-12  148.429993  150.399994  147.479996  149.990005  149.124512
#
#               Volume company_name
# Date
# 2021-11-08  55020900        APPLE
# 2021-11-09  56787900        APPLE
# 2021-11-10  65187100        APPLE
# 2021-11-11  41000000        APPLE
# 2021-11-12  63804000        APPLE

# %% [markdown]
# ##### Getting features

# %%
closeData = dataset.filter(['Close'])

# %% [markdown]
# ##### Normalisation

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(closeData)

# %%
closeData[:5].values, scaled_data[:5]
# Out:
# (array([[150.44000244],
#         [150.80999756],
#         [147.91999817],
#         [147.86999512],
#         [149.99000549]]),
#  array([[0.39230041],
#         [0.39942255],
#         [0.34379214],
#         [0.34282962],
#         [0.38363829]]))

# %% [markdown]
# ##### Getting input and output

# %%
training_data_len = int(len(scaled_data) * 0.9)
train_data = scaled_data[0:int(training_data_len), :]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
        
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
test_data = scaled_data[training_data_len - 60: , :]

x_test = []
y_test = closeData.values[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
x_test = np.array(x_test)

# %% [markdown]
# ##### Defining model, Training & Evaluating

# %% [markdown]
# ###### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
predictions = np.asarray(model.predict(x_test)).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("Linear Regression", rmse)

# Plot the data
train = dataset[:training_data_len]
valid = dataset[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Linear Regression')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.grid(0)
plt.show()
valid.head(5)
# Out:
# Linear Regression 3.3040094742980517
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.214081
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.858047
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.157532
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.189148
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.857986
#
#                Volume company_name  Predictions
# Date
# 2022-10-03  114311700        APPLE   139.944806
# 2022-10-04   87830100        APPLE   145.100478
# 2022-10-05   79471000        APPLE   143.718000
# 2022-10-06   68402200        APPLE   143.615510
# 2022-10-07   85859100        APPLE   143.436013

# %% [markdown]
# ###### XGBoost Regressor

# %%
from xgboost.sklearn import XGBRegressor

# %%
model = XGBRegressor()
model.fit(x_train, y_train)
predictions = np.asarray(model.predict(x_test)).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("XGB Regressor", rmse)

# Plot the data
train = dataset[:training_data_len]
valid = dataset[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('XGB Regressor')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.grid(0)
plt.show()
valid.head(5)
# Out:
# XGB Regressor 4.545149753460062
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.214081
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.858047
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.157532
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.189148
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.857986
#
#                Volume company_name  Predictions
# Date
# 2022-10-03  114311700        APPLE   139.372925
# 2022-10-04   87830100        APPLE   139.005173
# 2022-10-05   79471000        APPLE   145.577682
# 2022-10-06   68402200        APPLE   145.667938
# 2022-10-07   85859100        APPLE   145.741028

# %% [markdown]
# ###### Kernel Ridge Regression

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
model = KernelRidge()
model.fit(x_train, y_train)
predictions = np.asarray(model.predict(x_test)).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("Kernel Ridge Regressor", rmse)

# Plot the data
train = dataset[:training_data_len]
valid = dataset[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Kernel Ridge Regressor')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.grid(0)
plt.show()
valid.head(5)
# Out:
# Kernel Ridge Regressor 3.932195456977313
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.214081
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.858047
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.157532
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.189148
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.857986
#
#                Volume company_name  Predictions
# Date
# 2022-10-03  114311700        APPLE   141.758698
# 2022-10-04   87830100        APPLE   142.210369
# 2022-10-05   79471000        APPLE   143.016297
# 2022-10-06   68402200        APPLE   143.197045
# 2022-10-07   85859100        APPLE   142.965501

# %% [markdown]
# ###### Bayesian Ridge Regression

# %%
from sklearn.linear_model import BayesianRidge

# %%
model = BayesianRidge()
model.fit(x_train, y_train)
predictions = np.asarray(model.predict(x_test)).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("Bayesian Ridge Regressor", rmse)

# Plot the data
train = dataset[:training_data_len]
valid = dataset[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Bayesian Ridge Regressor')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.grid(0)
plt.show()

valid.head(5)
# Out:
# Bayesian Ridge Regressor 3.5238008180485307
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.214081
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.858047
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.157532
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.189148
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.857986
#
#                Volume company_name  Predictions
# Date
# 2022-10-03  114311700        APPLE   140.915142
# 2022-10-04   87830100        APPLE   143.287828
# 2022-10-05   79471000        APPLE   143.868986
# 2022-10-06   68402200        APPLE   143.656766
# 2022-10-07   85859100        APPLE   143.201955

# %% [markdown]
# ###### Support Vector Machine

# %%
from sklearn.svm import SVR

# %%
model = SVR()
model.fit(x_train, y_train)
predictions = np.asarray(model.predict(x_test)).reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("Support Vector Regressor", rmse)

# Plot the data
train = dataset[:training_data_len]
valid = dataset[training_data_len:]
valid['Predictions'] = predictions

# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Support Vector Regressor')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.grid(0)
plt.show()

valid.head(5)
# Out:
# Support Vector Regressor 6.551310708543046
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.214081
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.858047
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.157532
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.189148
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.857986
#
#                Volume company_name  Predictions
# Date
# 2022-10-03  114311700        APPLE   142.048676
# 2022-10-04   87830100        APPLE   142.114253
# 2022-10-05   79471000        APPLE   142.092342
# 2022-10-06   68402200        APPLE   142.277548
# 2022-10-07   85859100        APPLE   142.348133

# %%
df.to_csv("StockData.csv", index=False)
